# %% [markdown]
# <a href="https://colab.research.google.com/github/anusreemswork-a11y/-Hotel-Booking-Demand-Analysis/blob/main/hotelbooking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/hotel_bookings.csv")
# Out:
# /tmp/ipykernel_961/1501416233.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("/content/hotel_bookings.csv")

# %%
data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
print("Dataset shape:", data.shape)
# Out:
# Dataset shape: (58890, 32)

# %%
print("\nData Types:\n", data.dtypes)
# Out:
# Data Types:
#  hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
print("\nMissing Values:\n", data.isnull().sum())
# Out:
# Missing Values:
#  hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             478
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
print("\nSummary Statistics:\n", data.describe())
# Out:
# Summary Statistics:
#          is_canceled     lead_time  arrival_date_year  \
# count  58890.000000  58890.000000       58890.000000
# mean       0.411360    100.046714        2015.974597
# std        0.492084    101.157752           0.687274
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     17.000000        2016.000000
# 50%        0.000000     69.000000        2016.000000
# 75%        1.000000    157.000000        2016.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              58890.000000               58890.000000
# mean                  27.837426                  15.767159
# std                   13.346370                   8.783033
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   29.000000                  16.000000
# ...

# %%
print("\nCancellation Distribution:\n", data['is_canceled'].value_counts())
# Out:
# Cancellation Distribution:
#  is_canceled
# 0    34665
# 1    24225
# Name: count, dtype: int64

# %%
print("\nLead Time Summary:\n", data['lead_time'].describe())
# Out:
# Lead Time Summary:
#  count    58890.000000
# mean       100.046714
# std        101.157752
# min          0.000000
# 25%         17.000000
# 50%         69.000000
# 75%        157.000000
# max        737.000000
# Name: lead_time, dtype: float64

# %%
print("\nTop Countries:\n", data['country'].value_counts().head(10))
# Out:
# Top Countries:
#  country
# PRT    27556
# GBR     7595
# ESP     5274
# FRA     3037
# IRL     2371
# DEU     2021
# ITA     1290
# CN       807
# NLD      748
# BEL      733
# Name: count, dtype: int64

# %%
print("\nCustomer Types:\n", data['customer_type'].value_counts())
# Out:
# Customer Types:
#  customer_type
# Transient          42848
# Transient-Party    13212
# Contract            2513
# Group                316
# Name: count, dtype: int64
